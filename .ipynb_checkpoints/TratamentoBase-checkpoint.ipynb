# %%
#Import de bibliotecas a serem utilizdas
import pandas as pd
import numpy as np
import pymssql
from sqlalchemy.engine import URL,create_engine
from sqlalchemy_utils import database_exists, create_database

# %% [markdown]
# ## Leitura do Banco de dados

# %%
#Criação de conexão ao banco de dados para leitura
server_name = "DESKTOP-9RK4J8O"
db_name = "AdventureWorksDW2019"
connection_str =  'Driver={SQL Server};' + 'Server=' + server_name + ";Database=" + db_name + ";Trusted_Connection=yes;"

connection_url = URL.create("mssql+pyodbc", query={"odbc_connect": connection_str})
engine = create_engine(connection_url)
con = engine.connect()

# %%
#Leitura do banco de dados em um dataframe do pandas
FactFinance = pd.read_sql("SELECT * FROM dbo.FactFinance", con)
FactFinance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39409 entries, 0 to 39408
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   FinanceKey          39409 non-null  int64
#  1   DateKey             39409 non-null  int64
#  2   OrganizationKey     39409 non-null  int64
#  3   DepartmentGroupKey  39409 non-null  int64
#  4   ScenarioKey         39409 non-null  int64
#  5   AccountKey          39409 non-null  int64
#  6   Amount              39409 non-null  float64
#  7   Date                39409 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(6)
# memory usage: 2.4 MB

# %%
#Leitura das demais tabelas
DimAccount = pd.read_sql("SELECT * FROM dbo.DimAccount", con)
DimDate = pd.read_sql("SELECT * FROM dbo.DimDate", con)
DimDepartmentGroup = pd.read_sql("SELECT * FROM dbo.DimDepartmentGroup", con)
DimOrganization = pd.read_sql("SELECT * FROM dbo.DimOrganization", con)
DimScenario = pd.read_sql("SELECT * FROM dbo.DimScenario", con)
DimCurrency = pd.read_sql("SELECT * FROM dbo.DimCurrency", con)

# %%
#Verificando o nomes das colunas das tabelas carregadas
tabelas = [FactFinance,DimAccount,DimCurrency, DimOrganization,DimDate,DimDepartmentGroup,DimOrganization,DimScenario,DimCurrency]
for df in tabelas:
    print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39409 entries, 0 to 39408
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   FinanceKey          39409 non-null  int64
#  1   DateKey             39409 non-null  int64
#  2   OrganizationKey     39409 non-null  int64
#  3   DepartmentGroupKey  39409 non-null  int64
#  4   ScenarioKey         39409 non-null  int64
#  5   AccountKey          39409 non-null  int64
#  6   Amount              39409 non-null  float64
#  7   Date                39409 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(6)
# memory usage: 2.4 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   AccountKey                     99 non-null     int64
#  1   ParentAccountKey               96 non-null     float64
#  2   AccountCodeAlternateKey        99 non-null     int64
#  3   ParentAccountCodeAlternateKey  96 non-null     float64
#  4   AccountDescription             99 non-null     object
#  5   AccountType                    98 non-null     object
#  6   Operator                       99 non-null     object
#  7   CustomMembers                  1 non-null      object
#  8   ValueType                      99 non-null     object
#  9   CustomMemberOptions            0 non-null      object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 7.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CurrencyKey           105 non-null    int64
#  1   CurrencyAlternateKey  105 non-null    object
#  2   CurrencyName          105 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 2.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OrganizationKey        14 non-null     int64
#  1   ParentOrganizationKey  13 non-null     float64
#  2   PercentageOfOwnership  14 non-null     object
#  3   OrganizationName       14 non-null     object
#  4   CurrencyKey            14 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 688.0+ bytes
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3652 entries, 0 to 3651
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   DateKey               3652 non-null   int64
#  1   FullDateAlternateKey  3652 non-null   object
#  2   DayNumberOfWeek       3652 non-null   int64
#  3   EnglishDayNameOfWeek  3652 non-null   object
#  4   SpanishDayNameOfWeek  3652 non-null   object
#  5   FrenchDayNameOfWeek   3652 non-null   object
#  6   DayNumberOfMonth      3652 non-null   int64
#  7   DayNumberOfYear       3652 non-null   int64
#  8   WeekNumberOfYear      3652 non-null   int64
#  9   EnglishMonthName      3652 non-null   object
#  10  SpanishMonthName      3652 non-null   object
#  11  FrenchMonthName       3652 non-null   object
#  12  MonthNumberOfYear     3652 non-null   int64
#  13  CalendarQuarter       3652 non-null   int64
#  14  CalendarYear          3652 non-null   int64
#  15  CalendarSemester      3652 non-null   int64
#  16  FiscalQuarter         3652 non-null   int64
#  17  FiscalYear            3652 non-null   int64
#  18  FiscalSemester        3652 non-null   int64
# dtypes: int64(12), object(7)
# memory usage: 542.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DepartmentGroupKey        7 non-null      int64
#  1   ParentDepartmentGroupKey  6 non-null      float64
#  2   DepartmentGroupName       7 non-null      object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 296.0+ bytes
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OrganizationKey        14 non-null     int64
#  1   ParentOrganizationKey  13 non-null     float64
#  2   PercentageOfOwnership  14 non-null     object
#  3   OrganizationName       14 non-null     object
#  4   CurrencyKey            14 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 688.0+ bytes
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ScenarioKey   3 non-null      int64
#  1   ScenarioName  3 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CurrencyKey           105 non-null    int64
#  1   CurrencyAlternateKey  105 non-null    object
#  2   CurrencyName          105 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 2.6+ KB
# None

# %% [markdown]
# ## DimCurrency

# %%
DimCurrency.head()
# Out:
#    CurrencyKey CurrencyAlternateKey    CurrencyName
# 0            1                  AFA         Afghani
# 1            2                  DZD  Algerian Dinar
# 2            3                  ARS  Argentine Peso
# 3            4                  AMD   Armenian Dram
# 4            5                  AWG  Aruban Guilder

# %%
DimOrganization.head()
# Out:
#    OrganizationKey  ParentOrganizationKey PercentageOfOwnership  \
# 0                1                    NaN                     1
# 1                2                    1.0                     1
# 2                3                   14.0                     1
# 3                4                   14.0                     1
# 4                5                   14.0                     1
#
#            OrganizationName  CurrencyKey
# 0      AdventureWorks Cycle          100
# 1  North America Operations          100
# 2        Northeast Division          100
# 3        Northwest Division          100
# 4          Central Division          100

# %% [markdown]
# #### Irei utilizar apenas o nome da moeda em meu relatório, portanto irei levar essa informação da tabela DimCurrency para a DimOrganization a fim de simplificar o modelo e remover registros desnecessários

# %%
#Trazer os dados da currency para organization
DimOrganization_trat = DimOrganization.merge(DimCurrency, how='left', on='CurrencyKey')
DimOrganization_trat.head()
# Out:
#    OrganizationKey  ParentOrganizationKey PercentageOfOwnership  \
# 0                1                    NaN                     1
# 1                2                    1.0                     1
# 2                3                   14.0                     1
# 3                4                   14.0                     1
# 4                5                   14.0                     1
#
#            OrganizationName  CurrencyKey CurrencyAlternateKey CurrencyName
# 0      AdventureWorks Cycle          100                  USD    US Dollar
# 1  North America Operations          100                  USD    US Dollar
# 2        Northeast Division          100                  USD    US Dollar
# 3        Northwest Division          100                  USD    US Dollar
# 4          Central Division          100                  USD    US Dollar

# %%
#Trazer o nome das organizações 'pais' invés do código
DimOrganization_trat = DimOrganization_trat.merge(DimOrganization, how='left', left_on='ParentOrganizationKey',right_on='OrganizationKey')
DimOrganization_trat
# Out:
#     OrganizationKey_x  ParentOrganizationKey_x PercentageOfOwnership_x  \
# 0                   1                      NaN                       1
# 1                   2                      1.0                       1
# 2                   3                     14.0                       1
# 3                   4                     14.0                       1
# 4                   5                     14.0                       1
# 5                   6                     14.0                       1
# 6                   7                     14.0                       1
# 7                   8                      2.0                     .75
# 8                   9                      1.0                       1
# 9                  10                      1.0                     .75
# 10                 11                      9.0                     .50
# 11                 12                      9.0                     .25
# 12                 13                     10.0                     .50
# 13                 14                      2.0                       1
#
#           OrganizationName_x  CurrencyKey_x CurrencyAlternateKey  \
# 0       AdventureWorks Cycle            100                  USD
# 1   North America Operations            100                  USD
# 2         Northeast Division            100                  USD
# 3         Northwest Division            100                  USD
# 4           Central Division            100                  USD
# 5         Southeast Division            100                  USD
# 6         Southwest Division            100                  USD
# 7          Canadian Division             19                  CAD
# 8        European Operations             36                  EUR
# 9         Pacific Operations              6                  AUD
# 10                    France             36                  EUR
# 11                   Germany             36                  EUR
# 12                 Australia              6                  AUD
# 13            USA Operations            100                  USD
#
#          CurrencyName  OrganizationKey_y  ParentOrganizationKey_y  \
# 0           US Dollar                NaN                      NaN
# 1           US Dollar                1.0                      NaN
# 2           US Dollar               14.0                      2.0
# 3           US Dollar               14.0                      2.0
# 4           US Dollar               14.0                      2.0
# 5           US Dollar               14.0                      2.0
# 6           US Dollar               14.0                      2.0
# 7     Canadian Dollar                2.0                      1.0
# 8                EURO                1.0                      NaN
# 9   Australian Dollar                1.0                      NaN
# 10               EURO                9.0                      1.0
# 11               EURO                9.0                      1.0
# 12  Australian Dollar               10.0                      1.0
# 13          US Dollar                2.0                      1.0
#
#    PercentageOfOwnership_y        OrganizationName_y  CurrencyKey_y
# 0                      NaN                       NaN            NaN
# 1                        1      AdventureWorks Cycle          100.0
# 2                        1            USA Operations          100.0
# 3                        1            USA Operations          100.0
# 4                        1            USA Operations          100.0
# 5                        1            USA Operations          100.0
# 6                        1            USA Operations          100.0
# 7                        1  North America Operations          100.0
# 8                        1      AdventureWorks Cycle          100.0
# 9                        1      AdventureWorks Cycle          100.0
# 10                       1       European Operations           36.0
# 11                       1       European Operations           36.0
# 12                     .75        Pacific Operations            6.0
# 13                       1  North America Operations          100.0

# %%
#Seleção das colunas
DimOrganization_trat = DimOrganization_trat[["OrganizationKey_x","OrganizationName_x","OrganizationName_y","PercentageOfOwnership_x","CurrencyName"]]
DimOrganization_trat.head()
# Out:
#    OrganizationKey_x        OrganizationName_x    OrganizationName_y  \
# 0                  1      AdventureWorks Cycle                   NaN
# 1                  2  North America Operations  AdventureWorks Cycle
# 2                  3        Northeast Division        USA Operations
# 3                  4        Northwest Division        USA Operations
# 4                  5          Central Division        USA Operations
#
#   PercentageOfOwnership_x CurrencyName
# 0                       1    US Dollar
# 1                       1    US Dollar
# 2                       1    US Dollar
# 3                       1    US Dollar
# 4                       1    US Dollar

# %%
DimOrganization_trat
# Out:
#     OrganizationKey_x        OrganizationName_x        OrganizationName_y  \
# 0                   1      AdventureWorks Cycle                       NaN
# 1                   2  North America Operations      AdventureWorks Cycle
# 2                   3        Northeast Division            USA Operations
# 3                   4        Northwest Division            USA Operations
# 4                   5          Central Division            USA Operations
# 5                   6        Southeast Division            USA Operations
# 6                   7        Southwest Division            USA Operations
# 7                   8         Canadian Division  North America Operations
# 8                   9       European Operations      AdventureWorks Cycle
# 9                  10        Pacific Operations      AdventureWorks Cycle
# 10                 11                    France       European Operations
# 11                 12                   Germany       European Operations
# 12                 13                 Australia        Pacific Operations
# 13                 14            USA Operations  North America Operations
#
#    PercentageOfOwnership_x       CurrencyName
# 0                        1          US Dollar
# 1                        1          US Dollar
# 2                        1          US Dollar
# 3                        1          US Dollar
# 4                        1          US Dollar
# 5                        1          US Dollar
# 6                        1          US Dollar
# 7                      .75    Canadian Dollar
# 8                        1               EURO
# 9                      .75  Australian Dollar
# 10                     .50               EURO
# 11                     .25               EURO
# 12                     .50  Australian Dollar
# 13                       1          US Dollar

# %%
#Renomeação das colunas
DimOrganization_trat = DimOrganization_trat.rename(columns={"OrganizationKey_x":"OrganizationKey","OrganizationName_x":"OrganizationName","OrganizationName_y":"ParentOrganizationName","PercentageOfOwnership_x":"PercentageOfOwnership"})
DimOrganization_trat.head()
# Out:
#    OrganizationKey          OrganizationName ParentOrganizationName  \
# 0                1      AdventureWorks Cycle                    NaN
# 1                2  North America Operations   AdventureWorks Cycle
# 2                3        Northeast Division         USA Operations
# 3                4        Northwest Division         USA Operations
# 4                5          Central Division         USA Operations
#
#   PercentageOfOwnership CurrencyName
# 0                     1    US Dollar
# 1                     1    US Dollar
# 2                     1    US Dollar
# 3                     1    US Dollar
# 4                     1    US Dollar

# %% [markdown]
# ## DimOrganization

# %%
DimDepartmentGroup.head()
# Out:
#    DepartmentGroupKey  ParentDepartmentGroupKey  \
# 0                   1                       NaN
# 1                   2                       1.0
# 2                   3                       1.0
# 3                   4                       1.0
# 4                   5                       1.0
#
#                     DepartmentGroupName
# 0                             Corporate
# 1  Executive General and Administration
# 2                  Inventory Management
# 3                         Manufacturing
# 4                     Quality Assurance

# %% [markdown]
# ### Verifico que a DimDepartmentGroup também possui o código do "pai" invés do nome

# %%
#Trazer o nome dos grupos de departamentos 'pais' invés do código
DimDepartmentGroup_trat = DimDepartmentGroup.merge(DimDepartmentGroup, how='left', left_on='ParentDepartmentGroupKey',right_on='DepartmentGroupKey')
DimDepartmentGroup_trat
# Out:
#    DepartmentGroupKey_x  ParentDepartmentGroupKey_x  \
# 0                     1                         NaN
# 1                     2                         1.0
# 2                     3                         1.0
# 3                     4                         1.0
# 4                     5                         1.0
# 5                     6                         1.0
# 6                     7                         1.0
#
#                   DepartmentGroupName_x  DepartmentGroupKey_y  \
# 0                             Corporate                   NaN
# 1  Executive General and Administration                   1.0
# 2                  Inventory Management                   1.0
# 3                         Manufacturing                   1.0
# 4                     Quality Assurance                   1.0
# 5              Research and Development                   1.0
# 6                   Sales and Marketing                   1.0
#
#    ParentDepartmentGroupKey_y DepartmentGroupName_y
# 0                         NaN                   NaN
# 1                         NaN             Corporate
# 2                         NaN             Corporate
# 3                         NaN             Corporate
# 4                         NaN             Corporate
# 5                         NaN             Corporate
# 6                         NaN             Corporate

# %%
#Seleção das colunas
DimDepartmentGroup_trat = DimDepartmentGroup_trat[["DepartmentGroupKey_x","DepartmentGroupName_x","DepartmentGroupName_y"]]
DimDepartmentGroup_trat.head()
# Out:
#    DepartmentGroupKey_x                 DepartmentGroupName_x  \
# 0                     1                             Corporate
# 1                     2  Executive General and Administration
# 2                     3                  Inventory Management
# 3                     4                         Manufacturing
# 4                     5                     Quality Assurance
#
#   DepartmentGroupName_y
# 0                   NaN
# 1             Corporate
# 2             Corporate
# 3             Corporate
# 4             Corporate

# %%
#Renomeação das colunas
DimDepartmentGroup_trat = DimDepartmentGroup_trat.rename(columns={"DepartmentGroupKey_x":"DepartmentGroupKey","DepartmentGroupName_x":"DepartmentGroupName","DepartmentGroupName_y":"ParentDepartmentGroupName"})
DimDepartmentGroup_trat.head()
# Out:
#    DepartmentGroupKey                   DepartmentGroupName  \
# 0                   1                             Corporate
# 1                   2  Executive General and Administration
# 2                   3                  Inventory Management
# 3                   4                         Manufacturing
# 4                   5                     Quality Assurance
#
#   ParentDepartmentGroupName
# 0                       NaN
# 1                 Corporate
# 2                 Corporate
# 3                 Corporate
# 4                 Corporate

# %% [markdown]
# ## DimAccount

# %%
DimAccount.head()
# Out:
#    AccountKey  ParentAccountKey  AccountCodeAlternateKey  \
# 0           1               NaN                        1
# 1           2               1.0                       10
# 2           3               2.0                      110
# 3           4               3.0                     1110
# 4           5               3.0                     1120
#
#    ParentAccountCodeAlternateKey AccountDescription AccountType Operator  \
# 0                            NaN      Balance Sheet        None        ~
# 1                            1.0             Assets      Assets        +
# 2                           10.0     Current Assets      Assets        +
# 3                          110.0               Cash      Assets        +
# 4                          110.0        Receivables      Assets        +
#
#   CustomMembers ValueType CustomMemberOptions
# 0          None  Currency                None
# 1          None  Currency                None
# 2          None  Currency                None
# 3          None  Currency                None
# 4          None  Currency                None

# %%
#Removeção de colunas desnecessárias pois não trazem informação
DimAccount_trat = DimAccount[['AccountKey','ParentAccountKey','AccountDescription','AccountType','Operator','ValueType']]

# %% [markdown]
# ### Verifico que a DimAccount também possui o código do "pai" invés do nome

# %% [markdown]
# ### Investigarei o caracter ~ na coluna Operator, o padrão seria indicar uma operação positiva ou negativa

# %%
#Listar valores únicos da coluna Operator
DimAccount.Operator.unique()
# Out:
# array(['~', '+', '-'], dtype=object)

# %%
DimAccount[DimAccount['Operator'] == '~']
# Out:
#     AccountKey  ParentAccountKey  AccountCodeAlternateKey  \
# 0            1               NaN                        1
# 92          95               NaN                     9500
# 93          96              95.0                     9510
# 94          97              95.0                     9520
# 95          98              95.0                     9530
# 96          99              95.0                     9540
#
#     ParentAccountCodeAlternateKey    AccountDescription  AccountType Operator  \
# 0                             NaN         Balance Sheet         None        ~
# 92                            NaN  Statistical Accounts  Statistical        ~
# 93                         9500.0             Headcount     Balances        ~
# 94                         9500.0                 Units         Flow        ~
# 95                         9500.0    Average Unit Price     Balances        ~
# 96                         9500.0        Square Footage     Balances        ~
#
#                                         CustomMembers ValueType  \
# 0                                                None  Currency
# 92                                               None     Units
# 93                                               None     Units
# 94                                               None     Units
# 95  [Account].[Accounts].[Account Level 04].&[50]/...  Currency
# 96                                               None     Units
#
#    CustomMemberOptions
# 0                 None
# 92                None
# 93                None
# 94                None
# 95                None
# 96                None

# %%
#Verificação na tabela fato das accounts com operator ~
FactFinance[FactFinance['AccountKey'] == 1].head()
# Out:
# Empty DataFrame
# Columns: [FinanceKey, DateKey, OrganizationKey, DepartmentGroupKey, ScenarioKey, AccountKey, Amount, Date]
# Index: []

# %%
FactFinance[FactFinance['AccountKey'] == 95].head()
# Out:
# Empty DataFrame
# Columns: [FinanceKey, DateKey, OrganizationKey, DepartmentGroupKey, ScenarioKey, AccountKey, Amount, Date]
# Index: []

# %%
FactFinance[FactFinance['AccountKey'] == 96].head()
# Out:
#      FinanceKey   DateKey  OrganizationKey  DepartmentGroupKey  ScenarioKey  \
# 46           47  20101229                3                   1            1
# 106         107  20101229                3                   6            1
# 186         187  20101229                3                   7            1
# 234         235  20101229                4                   1            1
# 294         295  20101229                4                   6            1
#
#      AccountKey  Amount       Date
# 46           96    12.0 2010-12-29
# 106          96     8.0 2010-12-29
# 186          96     3.0 2010-12-29
# 234          96    11.0 2010-12-29
# 294          96     7.0 2010-12-29

# %% [markdown]
# ### Entre as Accounts que tem operator ~, duas não apresentaram registro na tabela fato, suponho que seja por serem 'pais'. As outras Accounts tem o ValueType como Units.

# %%
#Listar valores únicos da coluna ValueType
DimAccount.ValueType.unique()
# Out:
# array(['Currency', 'Units'], dtype=object)

# %%
#Verificação de registros com ValueType igual a Units
DimAccount[DimAccount['ValueType'] == 'Units']
# Out:
#     AccountKey  ParentAccountKey  AccountCodeAlternateKey  \
# 92          95               NaN                     9500
# 93          96              95.0                     9510
# 94          97              95.0                     9520
# 96          99              95.0                     9540
#
#     ParentAccountCodeAlternateKey    AccountDescription  AccountType Operator  \
# 92                            NaN  Statistical Accounts  Statistical        ~
# 93                         9500.0             Headcount     Balances        ~
# 94                         9500.0                 Units         Flow        ~
# 96                         9500.0        Square Footage     Balances        ~
#
#    CustomMembers ValueType CustomMemberOptions
# 92          None     Units                None
# 93          None     Units                None
# 94          None     Units                None
# 96          None     Units                None

# %% [markdown]
# ### Todos registros de ValueType igual a units estão contidos entre os registros de Operator igual a ~

# %% [markdown]
# ### Segundo a descrição destes registros indicam que contém informações diferentes, exemplo: metro quadrado. Irei desconsidera-los pois não se referem a Financeiro.

# %%
#Identificar quais códigos de conta tem operador ~
regRemov = DimAccount.AccountKey[DimAccount['Operator'] == '~'].tolist()

# %%
#Removendo na fato os registros referentes a estas accounts
FactFinance_trat = FactFinance[~FactFinance['AccountKey'].isin(regRemov)]

# %%
#Listar registros de Account que não tem 'pai'
DimAccount_trat[DimAccount_trat['ParentAccountKey'].isna()]
# Out:
#     AccountKey  ParentAccountKey    AccountDescription  AccountType Operator  \
# 0            1               NaN         Balance Sheet         None        ~
# 45          47               NaN            Net Income      Revenue        +
# 92          95               NaN  Statistical Accounts  Statistical        ~
#
#    ValueType
# 0   Currency
# 45  Currency
# 92     Units

# %%
#Verificando se a Account sem 'pai' que não foi listada entre os ~
FactFinance[FactFinance['AccountKey'] == 47].head()
# Out:
# Empty DataFrame
# Columns: [FinanceKey, DateKey, OrganizationKey, DepartmentGroupKey, ScenarioKey, AccountKey, Amount, Date]
# Index: []

# %% [markdown]
# ### Confirmo que os registros 'pai' de accounts não tem registro relacionado na fato

# %%
DimAccount.AccountType.unique()
# Out:
# array([None, 'Assets', 'Liabilities', 'Revenue', 'Expenditures',
#        'Statistical', 'Balances', 'Flow'], dtype=object)

# %% [markdown]
# ### Entendo que a coluna AccountType trás a informação da categoria geral. Sendo assim, utilizarei a coluna AccountDescription como relação com account 'pai'

# %%
#Trazer a descrição das accounts 'pais' invés do código
DimAccount_trat = DimAccount_trat.merge(DimAccount_trat, how='left', left_on='ParentAccountKey',right_on='AccountKey')
DimAccount_trat.head()
# Out:
#    AccountKey_x  ParentAccountKey_x AccountDescription_x AccountType_x  \
# 0             1                 NaN        Balance Sheet          None
# 1             2                 1.0               Assets        Assets
# 2             3                 2.0       Current Assets        Assets
# 3             4                 3.0                 Cash        Assets
# 4             5                 3.0          Receivables        Assets
#
#   Operator_x ValueType_x  AccountKey_y  ParentAccountKey_y  \
# 0          ~    Currency           NaN                 NaN
# 1          +    Currency           1.0                 NaN
# 2          +    Currency           2.0                 1.0
# 3          +    Currency           3.0                 2.0
# 4          +    Currency           3.0                 2.0
#
#   AccountDescription_y AccountType_y Operator_y ValueType_y
# 0                  NaN           NaN        NaN         NaN
# 1        Balance Sheet          None          ~    Currency
# 2               Assets        Assets          +    Currency
# 3       Current Assets        Assets          +    Currency
# 4       Current Assets        Assets          +    Currency

# %%
#Seleção das colunas
DimAccount_trat = DimAccount_trat[["AccountKey_x","AccountDescription_x","AccountDescription_y","AccountType_x","Operator_x"]]
DimAccount_trat.head()
# Out:
#    AccountKey_x AccountDescription_x AccountDescription_y AccountType_x  \
# 0             1        Balance Sheet                  NaN          None
# 1             2               Assets        Balance Sheet        Assets
# 2             3       Current Assets               Assets        Assets
# 3             4                 Cash       Current Assets        Assets
# 4             5          Receivables       Current Assets        Assets
#
#   Operator_x
# 0          ~
# 1          +
# 2          +
# 3          +
# 4          +

# %%
#Renomeação das colunas
DimAccount_trat = DimAccount_trat.rename(columns={"AccountKey_x":"AccountKey","AccountDescription_x":"AccountDescription","AccountDescription_y":"ParentAccountDescription","AccountType_x":"AccountType","Operator_x":"Operator"})
DimAccount_trat.head()
# Out:
#    AccountKey AccountDescription ParentAccountDescription AccountType Operator
# 0           1      Balance Sheet                      NaN        None        ~
# 1           2             Assets            Balance Sheet      Assets        +
# 2           3     Current Assets                   Assets      Assets        +
# 3           4               Cash           Current Assets      Assets        +
# 4           5        Receivables           Current Assets      Assets        +

# %%
#Removendo na dimensão os registros referentes as accounts igual a ~
DimAccount_trat = DimAccount_trat[~DimAccount_trat['AccountKey'].isin(regRemov)]

# %% [markdown]
# ## DimScenario

# %%
DimScenario.head()
# Out:
#    ScenarioKey ScenarioName
# 0            1       Actual
# 1            2       Budget
# 2            3     Forecast

# %% [markdown]
# ### Ter a informações contidas na tabela DimScenario como uma tabela separada é desnecessário e irei levar para a FactFinance

# %%
FactFinance_trat = pd.merge(FactFinance_trat, DimScenario, how='left', on = 'ScenarioKey')

# %% [markdown]
# ## FactFinance

# %%
FactFinance_trat.head()
# Out:
#    FinanceKey   DateKey  OrganizationKey  DepartmentGroupKey  ScenarioKey  \
# 0           1  20101229                3                   1            1
# 1           2  20101229                3                   1            2
# 2           3  20101229                3                   1            2
# 3           4  20101229                3                   1            1
# 4           5  20101229                3                   1            1
#
#    AccountKey   Amount       Date ScenarioName
# 0          60  22080.0 2010-12-29       Actual
# 1          60  20200.0 2010-12-29       Budget
# 2          61   2000.0 2010-12-29       Budget
# 3          61   2208.0 2010-12-29       Actual
# 4          62   1546.0 2010-12-29       Actual

# %%
#Seleção das colunas
FactFinance_trat = FactFinance_trat[["FinanceKey","DateKey","OrganizationKey","DepartmentGroupKey","AccountKey","Amount","ScenarioName"]]
FactFinance_trat.head()
# Out:
#    FinanceKey   DateKey  OrganizationKey  DepartmentGroupKey  AccountKey  \
# 0           1  20101229                3                   1          60
# 1           2  20101229                3                   1          60
# 2           3  20101229                3                   1          61
# 3           4  20101229                3                   1          61
# 4           5  20101229                3                   1          62
#
#     Amount ScenarioName
# 0  22080.0       Actual
# 1  20200.0       Budget
# 2   2000.0       Budget
# 3   2208.0       Actual
# 4   1546.0       Actual

# %% [markdown]
# ## Escrita no banco de dados

# %%
#Criação de conexão ao banco de dados para leitura
server_name = "DESKTOP-9RK4J8O"
db_name = "AdventureWorksTrat"
connection_str =  'Driver={SQL Server};' + 'Server=' + server_name + ";Database=" + db_name + ";Trusted_Connection=yes;"

connection_url = URL.create("mssql+pyodbc", query={"odbc_connect": connection_str})
engine = create_engine(connection_url)
con = engine.connect()

# %%
#Escrever as tabelas
FactFinance_trat.to_sql("FactFinance_trat", con)
DimAccount_trat.to_sql("DimAccount_trat", con)
DimDate.to_sql("DimDate_trat", con)
DimDepartmentGroup_trat.to_sql("DimDepartmentGroup_trat", con)
DimOrganization_trat.to_sql("DimOrganization_trat", con)
# Out:
# -1
