# %%
#Import de bibliotecas a serem utilizdas
import pandas as pd
import numpy as np
import pymssql
from sqlalchemy.engine import URL,create_engine
from sqlalchemy_utils import database_exists, create_database

# %% [markdown]
# ## Leitura do Banco de dados

# %%
#Criação de conexão ao banco de dados para leitura
server_name = "DESKTOP-9RK4J8O"
db_name = "AdventureWorksDW2019"
connection_str =  'Driver={SQL Server};' + 'Server=' + server_name + ";Database=" + db_name + ";Trusted_Connection=yes;"

connection_url = URL.create("mssql+pyodbc", query={"odbc_connect": connection_str})
engine = create_engine(connection_url)
con = engine.connect()

# %%
#Leitura do banco de dados em um dataframe do pandas
FactFinance = pd.read_sql("SELECT * FROM dbo.FactFinance", con)
FactFinance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39409 entries, 0 to 39408
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   FinanceKey          39409 non-null  int64
#  1   DateKey             39409 non-null  int64
#  2   OrganizationKey     39409 non-null  int64
#  3   DepartmentGroupKey  39409 non-null  int64
#  4   ScenarioKey         39409 non-null  int64
#  5   AccountKey          39409 non-null  int64
#  6   Amount              39409 non-null  float64
#  7   Date                39409 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(6)
# memory usage: 2.4 MB

# %%
#Leitura das demais tabelas
DimAccount = pd.read_sql("SELECT * FROM dbo.DimAccount", con)
DimDate = pd.read_sql("SELECT * FROM dbo.DimDate", con)
DimDepartmentGroup = pd.read_sql("SELECT * FROM dbo.DimDepartmentGroup", con)
DimOrganization = pd.read_sql("SELECT * FROM dbo.DimOrganization", con)
DimScenario = pd.read_sql("SELECT * FROM dbo.DimScenario", con)
DimCurrency = pd.read_sql("SELECT * FROM dbo.DimCurrency", con)

# %%
#Verificando o nomes das colunas das tabelas carregadas
tabelas = [FactFinance,DimAccount,DimCurrency, DimOrganization,DimDate,DimDepartmentGroup,DimOrganization,DimScenario,DimCurrency]
for df in tabelas:
    print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39409 entries, 0 to 39408
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   FinanceKey          39409 non-null  int64
#  1   DateKey             39409 non-null  int64
#  2   OrganizationKey     39409 non-null  int64
#  3   DepartmentGroupKey  39409 non-null  int64
#  4   ScenarioKey         39409 non-null  int64
#  5   AccountKey          39409 non-null  int64
#  6   Amount              39409 non-null  float64
#  7   Date                39409 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(6)
# memory usage: 2.4 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   AccountKey                     99 non-null     int64
#  1   ParentAccountKey               96 non-null     float64
#  2   AccountCodeAlternateKey        99 non-null     int64
#  3   ParentAccountCodeAlternateKey  96 non-null     float64
#  4   AccountDescription             99 non-null     object
#  5   AccountType                    98 non-null     object
#  6   Operator                       99 non-null     object
#  7   CustomMembers                  1 non-null      object
#  8   ValueType                      99 non-null     object
#  9   CustomMemberOptions            0 non-null      object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 7.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CurrencyKey           105 non-null    int64
#  1   CurrencyAlternateKey  105 non-null    object
#  2   CurrencyName          105 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 2.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OrganizationKey        14 non-null     int64
#  1   ParentOrganizationKey  13 non-null     float64
#  2   PercentageOfOwnership  14 non-null     object
#  3   OrganizationName       14 non-null     object
#  4   CurrencyKey            14 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 688.0+ bytes
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3652 entries, 0 to 3651
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   DateKey               3652 non-null   int64
#  1   FullDateAlternateKey  3652 non-null   object
#  2   DayNumberOfWeek       3652 non-null   int64
#  3   EnglishDayNameOfWeek  3652 non-null   object
#  4   SpanishDayNameOfWeek  3652 non-null   object
#  5   FrenchDayNameOfWeek   3652 non-null   object
#  6   DayNumberOfMonth      3652 non-null   int64
#  7   DayNumberOfYear       3652 non-null   int64
#  8   WeekNumberOfYear      3652 non-null   int64
#  9   EnglishMonthName      3652 non-null   object
#  10  SpanishMonthName      3652 non-null   object
#  11  FrenchMonthName       3652 non-null   object
#  12  MonthNumberOfYear     3652 non-null   int64
#  13  CalendarQuarter       3652 non-null   int64
#  14  CalendarYear          3652 non-null   int64
#  15  CalendarSemester      3652 non-null   int64
#  16  FiscalQuarter         3652 non-null   int64
#  17  FiscalYear            3652 non-null   int64
#  18  FiscalSemester        3652 non-null   int64
# dtypes: int64(12), object(7)
# memory usage: 542.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DepartmentGroupKey        7 non-null      int64
#  1   ParentDepartmentGroupKey  6 non-null      float64
#  2   DepartmentGroupName       7 non-null      object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 296.0+ bytes
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OrganizationKey        14 non-null     int64
#  1   ParentOrganizationKey  13 non-null     float64
#  2   PercentageOfOwnership  14 non-null     object
#  3   OrganizationName       14 non-null     object
#  4   CurrencyKey            14 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 688.0+ bytes
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ScenarioKey   3 non-null      int64
#  1   ScenarioName  3 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CurrencyKey           105 non-null    int64
#  1   CurrencyAlternateKey  105 non-null    object
#  2   CurrencyName          105 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 2.6+ KB
# None

# %% [markdown]
# ## DimCurrency

# %%
DimCurrency.head()
# Out:
#    CurrencyKey CurrencyAlternateKey    CurrencyName
# 0            1                  AFA         Afghani
# 1            2                  DZD  Algerian Dinar
# 2            3                  ARS  Argentine Peso
# 3            4                  AMD   Armenian Dram
# 4            5                  AWG  Aruban Guilder

# %%
DimOrganization.head()
# Out:
#    OrganizationKey  ParentOrganizationKey PercentageOfOwnership  \
# 0                1                    NaN                     1
# 1                2                    1.0                     1
# 2                3                   14.0                     1
# 3                4                   14.0                     1
# 4                5                   14.0                     1
#
#            OrganizationName  CurrencyKey
# 0      AdventureWorks Cycle          100
# 1  North America Operations          100
# 2        Northeast Division          100
# 3        Northwest Division          100
# 4          Central Division          100

# %% [markdown]
# #### Irei utilizar apenas o nome da moeda em meu relatório, portanto irei levar essa informação da tabela DimCurrency para a DimOrganization a fim de simplificar o modelo e remover registros desnecessários

# %%
#Trazer os dados da currency para organization
DimOrganization_trat = DimOrganization.merge(DimCurrency, how='left', on='CurrencyKey')
DimOrganization_trat.head()
# Out:
#    OrganizationKey  ParentOrganizationKey PercentageOfOwnership  \
# 0                1                    NaN                     1
# 1                2                    1.0                     1
# 2                3                   14.0                     1
# 3                4                   14.0                     1
# 4                5                   14.0                     1
#
#            OrganizationName  CurrencyKey CurrencyAlternateKey CurrencyName
# 0      AdventureWorks Cycle          100                  USD    US Dollar
# 1  North America Operations          100                  USD    US Dollar
# 2        Northeast Division          100                  USD    US Dollar
# 3        Northwest Division          100                  USD    US Dollar
# 4          Central Division          100                  USD    US Dollar

# %%
#Fitrando colunas
DimOrganization_trat = DimOrganization_trat[["OrganizationKey","ParentOrganizationKey","OrganizationName","CurrencyName"]]
DimOrganization_trat.head()
# Out:
#    OrganizationKey  ParentOrganizationKey          OrganizationName  \
# 0                1                    NaN      AdventureWorks Cycle
# 1                2                    1.0  North America Operations
# 2                3                   14.0        Northeast Division
# 3                4                   14.0        Northwest Division
# 4                5                   14.0          Central Division
#
#   CurrencyName
# 0    US Dollar
# 1    US Dollar
# 2    US Dollar
# 3    US Dollar
# 4    US Dollar

# %% [markdown]
# ## DimOrganization

# %%
#Mapeando as hierarquias
OrgHier = DimOrganization_trat[["OrganizationKey","ParentOrganizationKey"]]
OrgHier = OrgHier.rename(columns={"OrganizationKey":"ParentOrganizationKey","ParentOrganizationKey":"ParentOrganizationKey2"})
OrgHier.head()
# Out:
#    ParentOrganizationKey  ParentOrganizationKey2
# 0                      1                     NaN
# 1                      2                     1.0
# 2                      3                    14.0
# 3                      4                    14.0
# 4                      5                    14.0

# %%
#Acrescentando hierarquias em colunas
DimOrganization_trat2 = DimOrganization_trat.merge(OrgHier, how='left', on='ParentOrganizationKey')
DimOrganization_trat2.head()
# Out:
#    OrganizationKey  ParentOrganizationKey          OrganizationName  \
# 0                1                    NaN      AdventureWorks Cycle
# 1                2                    1.0  North America Operations
# 2                3                   14.0        Northeast Division
# 3                4                   14.0        Northwest Division
# 4                5                   14.0          Central Division
#
#   CurrencyName  ParentOrganizationKey2
# 0    US Dollar                     NaN
# 1    US Dollar                     NaN
# 2    US Dollar                     2.0
# 3    US Dollar                     2.0
# 4    US Dollar                     2.0

# %%
#Acrescentando hierarquias em colunas
OrgHier = OrgHier.rename(columns={"ParentOrganizationKey":"ParentOrganizationKey2","ParentOrganizationKey2":"ParentOrganizationKey3"})
DimOrganization_trat3 = DimOrganization_trat2.merge(OrgHier, how='left', on='ParentOrganizationKey2')
DimOrganization_trat3
# Out:
#     OrganizationKey  ParentOrganizationKey          OrganizationName  \
# 0                 1                    NaN      AdventureWorks Cycle
# 1                 2                    1.0  North America Operations
# 2                 3                   14.0        Northeast Division
# 3                 4                   14.0        Northwest Division
# 4                 5                   14.0          Central Division
# 5                 6                   14.0        Southeast Division
# 6                 7                   14.0        Southwest Division
# 7                 8                    2.0         Canadian Division
# 8                 9                    1.0       European Operations
# 9                10                    1.0        Pacific Operations
# 10               11                    9.0                    France
# 11               12                    9.0                   Germany
# 12               13                   10.0                 Australia
# 13               14                    2.0            USA Operations
#
#          CurrencyName  ParentOrganizationKey2  ParentOrganizationKey3
# 0           US Dollar                     NaN                     NaN
# 1           US Dollar                     NaN                     NaN
# 2           US Dollar                     2.0                     1.0
# 3           US Dollar                     2.0                     1.0
# 4           US Dollar                     2.0                     1.0
# 5           US Dollar                     2.0                     1.0
# 6           US Dollar                     2.0                     1.0
# 7     Canadian Dollar                     1.0                     NaN
# 8                EURO                     NaN                     NaN
# 9   Australian Dollar                     NaN                     NaN
# 10               EURO                     1.0                     NaN
# 11               EURO                     1.0                     NaN
# 12  Australian Dollar                     1.0                     NaN
# 13          US Dollar                     1.0                     NaN

# %%
#Identificar quais codigos de org tem na fato
regOrg = FactFinance.OrganizationKey.unique()
#Filtrando registros da Organization que tem na fato
DimOrganization_trat4 = DimOrganization_trat3[DimOrganization_trat3['OrganizationKey'].isin(regOrg)]
DimOrganization_trat4
# Out:
#     OrganizationKey  ParentOrganizationKey    OrganizationName  \
# 2                 3                   14.0  Northeast Division
# 3                 4                   14.0  Northwest Division
# 4                 5                   14.0    Central Division
# 5                 6                   14.0  Southeast Division
# 6                 7                   14.0  Southwest Division
# 7                 8                    2.0   Canadian Division
# 10               11                    9.0              France
# 11               12                    9.0             Germany
# 12               13                   10.0           Australia
#
#          CurrencyName  ParentOrganizationKey2  ParentOrganizationKey3
# 2           US Dollar                     2.0                     1.0
# 3           US Dollar                     2.0                     1.0
# 4           US Dollar                     2.0                     1.0
# 5           US Dollar                     2.0                     1.0
# 6           US Dollar                     2.0                     1.0
# 7     Canadian Dollar                     1.0                     NaN
# 10               EURO                     1.0                     NaN
# 11               EURO                     1.0                     NaN
# 12  Australian Dollar                     1.0                     NaN

# %%
#Separando os registros para ajuste de hierarquia
DimOrganization_trat5 = DimOrganization_trat4[DimOrganization_trat4['ParentOrganizationKey3'].notna()]
DimOrganization_trat5 = DimOrganization_trat5.rename(columns={"ParentOrganizationKey":"CountryName","OrganizationName":"DivisionName","ParentOrganizationKey2":"OperationName","ParentOrganizationKey3":"CycleName"})
DimOrganization_trat5.head()
# Out:
#    OrganizationKey  CountryName        DivisionName CurrencyName  \
# 2                3         14.0  Northeast Division    US Dollar
# 3                4         14.0  Northwest Division    US Dollar
# 4                5         14.0    Central Division    US Dollar
# 5                6         14.0  Southeast Division    US Dollar
# 6                7         14.0  Southwest Division    US Dollar
#
#    OperationName  CycleName
# 2            2.0        1.0
# 3            2.0        1.0
# 4            2.0        1.0
# 5            2.0        1.0
# 6            2.0        1.0

# %%
#Separando os registros para ajuste de hierarquia
DimAux = DimOrganization_trat4[DimOrganization_trat4['ParentOrganizationKey3'].isna()]
DimAux = DimAux.rename(columns={"ParentOrganizationKey":"OperationName","OrganizationName":"CountryName","ParentOrganizationKey2":"CycleName","ParentOrganizationKey3":"DivisionName"})
DimAux.head()
# Out:
#     OrganizationKey  OperationName        CountryName       CurrencyName  \
# 7                 8            2.0  Canadian Division    Canadian Dollar
# 10               11            9.0             France               EURO
# 11               12            9.0            Germany               EURO
# 12               13           10.0          Australia  Australian Dollar
#
#     CycleName  DivisionName
# 7         1.0           NaN
# 10        1.0           NaN
# 11        1.0           NaN
# 12        1.0           NaN

# %%
#Junção dos registros
DimOrganization_trat6 = pd.concat([DimOrganization_trat5,DimAux])
DimOrganization_trat6
# Out:
#     OrganizationKey        CountryName        DivisionName       CurrencyName  \
# 2                 3               14.0  Northeast Division          US Dollar
# 3                 4               14.0  Northwest Division          US Dollar
# 4                 5               14.0    Central Division          US Dollar
# 5                 6               14.0  Southeast Division          US Dollar
# 6                 7               14.0  Southwest Division          US Dollar
# 7                 8  Canadian Division                 NaN    Canadian Dollar
# 10               11             France                 NaN               EURO
# 11               12            Germany                 NaN               EURO
# 12               13          Australia                 NaN  Australian Dollar
#
#     OperationName  CycleName
# 2             2.0        1.0
# 3             2.0        1.0
# 4             2.0        1.0
# 5             2.0        1.0
# 6             2.0        1.0
# 7             2.0        1.0
# 10            9.0        1.0
# 11            9.0        1.0
# 12           10.0        1.0

# %%
#Substituindo os códigos pelos nomes
OrgName = pd.Series(DimOrganization_trat.OrganizationName.values,index=DimOrganization_trat.OrganizationKey).to_dict()
DimOrganization_trat7 = DimOrganization_trat6.replace({"CountryName": OrgName,"OperationName": OrgName,"CycleName": OrgName})
DimOrganization_trat7
# Out:
#     OrganizationKey        CountryName        DivisionName       CurrencyName  \
# 2                 3     USA Operations  Northeast Division          US Dollar
# 3                 4     USA Operations  Northwest Division          US Dollar
# 4                 5     USA Operations    Central Division          US Dollar
# 5                 6     USA Operations  Southeast Division          US Dollar
# 6                 7     USA Operations  Southwest Division          US Dollar
# 7                 8  Canadian Division                 NaN    Canadian Dollar
# 10               11             France                 NaN               EURO
# 11               12            Germany                 NaN               EURO
# 12               13          Australia                 NaN  Australian Dollar
#
#                OperationName             CycleName
# 2   North America Operations  AdventureWorks Cycle
# 3   North America Operations  AdventureWorks Cycle
# 4   North America Operations  AdventureWorks Cycle
# 5   North America Operations  AdventureWorks Cycle
# 6   North America Operations  AdventureWorks Cycle
# 7   North America Operations  AdventureWorks Cycle
# 10       European Operations  AdventureWorks Cycle
# 11       European Operations  AdventureWorks Cycle
# 12        Pacific Operations  AdventureWorks Cycle

# %%
#Reordenando
DimOrganization_trat7 = DimOrganization_trat7[["OrganizationKey","DivisionName","CountryName","OperationName","CycleName","CurrencyName"]]
DimOrganization_trat7.head()
# Out:
#    OrganizationKey        DivisionName     CountryName  \
# 2                3  Northeast Division  USA Operations
# 3                4  Northwest Division  USA Operations
# 4                5    Central Division  USA Operations
# 5                6  Southeast Division  USA Operations
# 6                7  Southwest Division  USA Operations
#
#               OperationName             CycleName CurrencyName
# 2  North America Operations  AdventureWorks Cycle    US Dollar
# 3  North America Operations  AdventureWorks Cycle    US Dollar
# 4  North America Operations  AdventureWorks Cycle    US Dollar
# 5  North America Operations  AdventureWorks Cycle    US Dollar
# 6  North America Operations  AdventureWorks Cycle    US Dollar

# %% [markdown]
# ## DimDepartment

# %%
DimDepartmentGroup.head()
# Out:
#    DepartmentGroupKey  ParentDepartmentGroupKey  \
# 0                   1                       NaN
# 1                   2                       1.0
# 2                   3                       1.0
# 3                   4                       1.0
# 4                   5                       1.0
#
#                     DepartmentGroupName
# 0                             Corporate
# 1  Executive General and Administration
# 2                  Inventory Management
# 3                         Manufacturing
# 4                     Quality Assurance

# %% [markdown]
# ### Verifico que a DimDepartmentGroup também possui o código do "pai" invés do nome

# %%
#Trazer o nome dos grupos de departamentos 'pais' invés do código
DimDepartmentGroup_trat = DimDepartmentGroup.merge(DimDepartmentGroup, how='left', left_on='ParentDepartmentGroupKey',right_on='DepartmentGroupKey')
DimDepartmentGroup_trat
# Out:
#    DepartmentGroupKey_x  ParentDepartmentGroupKey_x  \
# 0                     1                         NaN
# 1                     2                         1.0
# 2                     3                         1.0
# 3                     4                         1.0
# 4                     5                         1.0
# 5                     6                         1.0
# 6                     7                         1.0
#
#                   DepartmentGroupName_x  DepartmentGroupKey_y  \
# 0                             Corporate                   NaN
# 1  Executive General and Administration                   1.0
# 2                  Inventory Management                   1.0
# 3                         Manufacturing                   1.0
# 4                     Quality Assurance                   1.0
# 5              Research and Development                   1.0
# 6                   Sales and Marketing                   1.0
#
#    ParentDepartmentGroupKey_y DepartmentGroupName_y
# 0                         NaN                   NaN
# 1                         NaN             Corporate
# 2                         NaN             Corporate
# 3                         NaN             Corporate
# 4                         NaN             Corporate
# 5                         NaN             Corporate
# 6                         NaN             Corporate

# %%
#Seleção das colunas
DimDepartmentGroup_trat2 = DimDepartmentGroup_trat[["DepartmentGroupKey_x","DepartmentGroupName_x","DepartmentGroupName_y"]]
DimDepartmentGroup_trat2.head()
# Out:
#    DepartmentGroupKey_x                 DepartmentGroupName_x  \
# 0                     1                             Corporate
# 1                     2  Executive General and Administration
# 2                     3                  Inventory Management
# 3                     4                         Manufacturing
# 4                     5                     Quality Assurance
#
#   DepartmentGroupName_y
# 0                   NaN
# 1             Corporate
# 2             Corporate
# 3             Corporate
# 4             Corporate

# %%
#Renomeação das colunas
DimDepartmentGroup_trat3 = DimDepartmentGroup_trat2.rename(columns={"DepartmentGroupKey_x":"DepartmentGroupKey","DepartmentGroupName_x":"DepartmentGroupName","DepartmentGroupName_y":"ParentDepartmentGroupName"})
DimDepartmentGroup_trat3.head()
# Out:
#    DepartmentGroupKey                   DepartmentGroupName  \
# 0                   1                             Corporate
# 1                   2  Executive General and Administration
# 2                   3                  Inventory Management
# 3                   4                         Manufacturing
# 4                   5                     Quality Assurance
#
#   ParentDepartmentGroupName
# 0                       NaN
# 1                 Corporate
# 2                 Corporate
# 3                 Corporate
# 4                 Corporate

# %%
DimDepartmentGroup_trat3.loc[0] = [1,'Corporate','Corporate']
DimDepartmentGroup_trat3
# Out:
#    DepartmentGroupKey                   DepartmentGroupName  \
# 0                   1                             Corporate
# 1                   2  Executive General and Administration
# 2                   3                  Inventory Management
# 3                   4                         Manufacturing
# 4                   5                     Quality Assurance
# 5                   6              Research and Development
# 6                   7                   Sales and Marketing
#
#   ParentDepartmentGroupName
# 0                 Corporate
# 1                 Corporate
# 2                 Corporate
# 3                 Corporate
# 4                 Corporate
# 5                 Corporate
# 6                 Corporate

# %% [markdown]
# ## DimAccount

# %%
DimAccount.head()
# Out:
#    AccountKey  ParentAccountKey  AccountCodeAlternateKey  \
# 0           1               NaN                        1
# 1           2               1.0                       10
# 2           3               2.0                      110
# 3           4               3.0                     1110
# 4           5               3.0                     1120
#
#    ParentAccountCodeAlternateKey AccountDescription AccountType Operator  \
# 0                            NaN      Balance Sheet        None        ~
# 1                            1.0             Assets      Assets        +
# 2                           10.0     Current Assets      Assets        +
# 3                          110.0               Cash      Assets        +
# 4                          110.0        Receivables      Assets        +
#
#   CustomMembers ValueType CustomMemberOptions
# 0          None  Currency                None
# 1          None  Currency                None
# 2          None  Currency                None
# 3          None  Currency                None
# 4          None  Currency                None

# %%
#Removeção de colunas desnecessárias pois não trazem informação
DimAccount_trat = DimAccount[['AccountKey','ParentAccountKey','AccountDescription','AccountType','Operator','ValueType']]
DimAccount_trat.head()
# Out:
#    AccountKey  ParentAccountKey AccountDescription AccountType Operator  \
# 0           1               NaN      Balance Sheet        None        ~
# 1           2               1.0             Assets      Assets        +
# 2           3               2.0     Current Assets      Assets        +
# 3           4               3.0               Cash      Assets        +
# 4           5               3.0        Receivables      Assets        +
#
#   ValueType
# 0  Currency
# 1  Currency
# 2  Currency
# 3  Currency
# 4  Currency

# %% [markdown]
# ### Desconsiderarei registros da fato onde a account tenha operator igual a ~ ou ValueType igual a units

# %%
#Identificar quais códigos de conta tem operador ~
regRemovOpe = DimAccount.AccountKey[DimAccount['Operator'] == '~'].tolist()
#Removendo na fato os registros referentes a estas accounts
FactFinance_trat = FactFinance[~FactFinance['AccountKey'].isin(regRemovOpe)]

# %%
#Identificar quais códigos de conta tem ValueType igual a units
regRemovTyp = DimAccount.AccountKey[DimAccount['ValueType'] == 'Units'].tolist()
#Removendo na fato os registros referentes a estas accounts
FactFinance_trat2 = FactFinance_trat[~FactFinance_trat['AccountKey'].isin(regRemovTyp)]

# %%
#Mapeando as hierarquias
AccHier = DimAccount_trat[["AccountKey","ParentAccountKey"]]
AccHier = AccHier.rename(columns={"AccountKey":"ParentAccountKey","ParentAccountKey":"ParentAccountKey2"})
AccHier.head()
# Out:
#    ParentAccountKey  ParentAccountKey2
# 0                 1                NaN
# 1                 2                1.0
# 2                 3                2.0
# 3                 4                3.0
# 4                 5                3.0

# %%
#Acrescentando hierarquias em colunas
DimAccount_trat2 = DimAccount_trat.merge(AccHier, how='left', on='ParentAccountKey')
DimAccount_trat2.head()
# Out:
#    AccountKey  ParentAccountKey AccountDescription AccountType Operator  \
# 0           1               NaN      Balance Sheet        None        ~
# 1           2               1.0             Assets      Assets        +
# 2           3               2.0     Current Assets      Assets        +
# 3           4               3.0               Cash      Assets        +
# 4           5               3.0        Receivables      Assets        +
#
#   ValueType  ParentAccountKey2
# 0  Currency                NaN
# 1  Currency                NaN
# 2  Currency                1.0
# 3  Currency                2.0
# 4  Currency                2.0

# %%
#Acrescentando hierarquias em colunas
AccHier = AccHier.rename(columns={"ParentAccountKey":"ParentAccountKey2","ParentAccountKey2":"ParentAccountKey3"})
DimAccount_trat3 = DimAccount_trat2.merge(AccHier, how='left', on='ParentAccountKey2')
DimAccount_trat3.head()
# Out:
#    AccountKey  ParentAccountKey AccountDescription AccountType Operator  \
# 0           1               NaN      Balance Sheet        None        ~
# 1           2               1.0             Assets      Assets        +
# 2           3               2.0     Current Assets      Assets        +
# 3           4               3.0               Cash      Assets        +
# 4           5               3.0        Receivables      Assets        +
#
#   ValueType  ParentAccountKey2  ParentAccountKey3
# 0  Currency                NaN                NaN
# 1  Currency                NaN                NaN
# 2  Currency                1.0                NaN
# 3  Currency                2.0                1.0
# 4  Currency                2.0                1.0

# %%
#Acrescentando hierarquias em colunas
AccHier = AccHier.rename(columns={"ParentAccountKey2":"ParentAccountKey3","ParentAccountKey3":"ParentAccountKey4"})
DimAccount_trat4 = DimAccount_trat3.merge(AccHier, how='left', on='ParentAccountKey3')
DimAccount_trat4.head()
# Out:
#    AccountKey  ParentAccountKey AccountDescription AccountType Operator  \
# 0           1               NaN      Balance Sheet        None        ~
# 1           2               1.0             Assets      Assets        +
# 2           3               2.0     Current Assets      Assets        +
# 3           4               3.0               Cash      Assets        +
# 4           5               3.0        Receivables      Assets        +
#
#   ValueType  ParentAccountKey2  ParentAccountKey3  ParentAccountKey4
# 0  Currency                NaN                NaN                NaN
# 1  Currency                NaN                NaN                NaN
# 2  Currency                1.0                NaN                NaN
# 3  Currency                2.0                1.0                NaN
# 4  Currency                2.0                1.0                NaN

# %%
#Acrescentando hierarquias em colunas
AccHier = AccHier.rename(columns={"ParentAccountKey3":"ParentAccountKey4","ParentAccountKey4":"ParentAccountKey5"})
DimAccount_trat5 = DimAccount_trat4.merge(AccHier, how='left', on='ParentAccountKey4')
DimAccount_trat5.head()
# Out:
#    AccountKey  ParentAccountKey AccountDescription AccountType Operator  \
# 0           1               NaN      Balance Sheet        None        ~
# 1           2               1.0             Assets      Assets        +
# 2           3               2.0     Current Assets      Assets        +
# 3           4               3.0               Cash      Assets        +
# 4           5               3.0        Receivables      Assets        +
#
#   ValueType  ParentAccountKey2  ParentAccountKey3  ParentAccountKey4  \
# 0  Currency                NaN                NaN                NaN
# 1  Currency                NaN                NaN                NaN
# 2  Currency                1.0                NaN                NaN
# 3  Currency                2.0                1.0                NaN
# 4  Currency                2.0                1.0                NaN
#
#    ParentAccountKey5
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
#Identificar quais codigos de org tem na fato
regAcc = FactFinance_trat2.AccountKey.unique()
#Filtrando registros da Organization que tem na fato
DimAccount_trat6 = DimAccount_trat5[DimAccount_trat5['AccountKey'].isin(regAcc)]
DimAccount_trat7 = DimAccount_trat6[["AccountKey","AccountDescription","ParentAccountKey","ParentAccountKey2","ParentAccountKey3","ParentAccountKey4","ParentAccountKey5","AccountType"]]
DimAccount_trat7
# Out:
#     AccountKey                      AccountDescription  ParentAccountKey  \
# 3            4                                    Cash               3.0
# 5            6                       Trade Receivables               5.0
# 6            7                       Other Receivables               5.0
# 7            8                  Allowance for Bad Debt               3.0
# 9           10                           Raw Materials               9.0
# ..         ...                                     ...               ...
# 89          92                            Other Income              88.0
# 90          93                   Curr Xchg Gain/(Loss)              88.0
# 91          94                                   Taxes              47.0
# 97         100  Current Installments of Long-term Debt              27.0
# 98         101                             Trade Sales              51.0
#
#     ParentAccountKey2  ParentAccountKey3  ParentAccountKey4  \
# 3                 2.0                1.0                NaN
# 5                 3.0                2.0                1.0
# 6                 3.0                2.0                1.0
# 7                 2.0                1.0                NaN
# 9                 3.0                2.0                1.0
# ..                ...                ...                ...
# 89               47.0                NaN                NaN
# 90               47.0                NaN                NaN
# 91                NaN                NaN                NaN
# 97               26.0               25.0                1.0
# 98               50.0               49.0               48.0
#
#     ParentAccountKey5   AccountType
# 3                 NaN        Assets
# 5                 NaN        Assets
# 6                 NaN        Assets
# 7                 NaN        Assets
# 9                 NaN        Assets
# ..                ...           ...
# 89                NaN       Revenue
# 90                NaN       Revenue
# 91                NaN  Expenditures
# 97                NaN   Liabilities
# 98               47.0       Revenue
#
# [68 rows x 8 columns]

# %%
#Separando os registros para ajuste de hierarquia
AccAux6 = DimAccount_trat7[DimAccount_trat7['ParentAccountKey5'].notna()]
AccAux6 = AccAux6.rename(columns={"AccountDescription":"AccountDescriptionNv6","ParentAccountKey":"AccountDescriptionNv5","ParentAccountKey2":"AccountDescriptionNv4","ParentAccountKey3":"AccountDescriptionNv3","ParentAccountKey4":"AccountDescriptionNv2","ParentAccountKey5":"AccountDescriptionNv1"})
AccAux6.head()
# Out:
#     AccountKey AccountDescriptionNv6  AccountDescriptionNv5  \
# 29          31   Salary & Other Comp                   30.0
# 30          32             Insurance                   30.0
# 31          33            Warranties                   30.0
# 50          52    Intercompany Sales                   51.0
# 98         101           Trade Sales                   51.0
#
#     AccountDescriptionNv4  AccountDescriptionNv3  AccountDescriptionNv2  \
# 29                   27.0                   26.0                   25.0
# 30                   27.0                   26.0                   25.0
# 31                   27.0                   26.0                   25.0
# 50                   50.0                   49.0                   48.0
# 98                   50.0                   49.0                   48.0
#
#     AccountDescriptionNv1  AccountType
# 29                    1.0  Liabilities
# 30                    1.0  Liabilities
# 31                    1.0  Liabilities
# 50                   47.0      Revenue
# 98                   47.0      Revenue

# %%
#Separando os registros para ajuste de hierarquia
AccAux5 = DimAccount_trat7[DimAccount_trat7['ParentAccountKey5'].isna() & DimAccount_trat7['ParentAccountKey4'].notna()]
AccAux5 = AccAux5.rename(columns={"AccountDescription":"AccountDescriptionNv5","ParentAccountKey":"AccountDescriptionNv4","ParentAccountKey2":"AccountDescriptionNv3","ParentAccountKey3":"AccountDescriptionNv2","ParentAccountKey4":"AccountDescriptionNv1","ParentAccountKey5":"AccountDescriptionNv6"})
AccAux5.head()
# Out:
#     AccountKey AccountDescriptionNv5  AccountDescriptionNv4  \
# 5            6     Trade Receivables                    5.0
# 6            7     Other Receivables                    5.0
# 9           10         Raw Materials                    9.0
# 10          11       Work in Process                    9.0
# 11          12        Finished Goods                    9.0
#
#     AccountDescriptionNv3  AccountDescriptionNv2  AccountDescriptionNv1  \
# 5                     3.0                    2.0                    1.0
# 6                     3.0                    2.0                    1.0
# 9                     3.0                    2.0                    1.0
# 10                    3.0                    2.0                    1.0
# 11                    3.0                    2.0                    1.0
#
#     AccountDescriptionNv6 AccountType
# 5                     NaN      Assets
# 6                     NaN      Assets
# 9                     NaN      Assets
# 10                    NaN      Assets
# 11                    NaN      Assets

# %%
#Separando os registros para ajuste de hierarquia
AccAux4 = DimAccount_trat7[DimAccount_trat7['ParentAccountKey4'].isna() & DimAccount_trat7['ParentAccountKey3'].notna()]
AccAux4 = AccAux4.rename(columns={"AccountDescription":"AccountDescriptionNv4","ParentAccountKey":"AccountDescriptionNv3","ParentAccountKey2":"AccountDescriptionNv2","ParentAccountKey3":"AccountDescriptionNv1","ParentAccountKey4":"AccountDescriptionNv6","ParentAccountKey5":"AccountDescriptionNv5"})
AccAux4.head()
# Out:
#     AccountKey     AccountDescriptionNv4  AccountDescriptionNv3  \
# 3            4                      Cash                    3.0
# 7            8    Allowance for Bad Debt                    3.0
# 12          13            Deferred Taxes                    3.0
# 13          14          Prepaid Expenses                    3.0
# 14          15  Intercompany Receivables                    3.0
#
#     AccountDescriptionNv2  AccountDescriptionNv1  AccountDescriptionNv6  \
# 3                     2.0                    1.0                    NaN
# 7                     2.0                    1.0                    NaN
# 12                    2.0                    1.0                    NaN
# 13                    2.0                    1.0                    NaN
# 14                    2.0                    1.0                    NaN
#
#     AccountDescriptionNv5 AccountType
# 3                     NaN      Assets
# 7                     NaN      Assets
# 12                    NaN      Assets
# 13                    NaN      Assets
# 14                    NaN      Assets

# %%
#Separando os registros para ajuste de hierarquia
AccAux3 = DimAccount_trat7[DimAccount_trat7['ParentAccountKey3'].isna() & DimAccount_trat7['ParentAccountKey2'].notna()]
AccAux3 = AccAux3.rename(columns={"AccountDescription":"AccountDescriptionNv3","ParentAccountKey":"AccountDescriptionNv2","ParentAccountKey2":"AccountDescriptionNv1","ParentAccountKey3":"AccountDescriptionNv6","ParentAccountKey4":"AccountDescriptionNv5","ParentAccountKey5":"AccountDescriptionNv4"})
AccAux3.head()
# Out:
#     AccountKey        AccountDescriptionNv3  AccountDescriptionNv2  \
# 22          24                 Other Assets                    2.0
# 86          89              Interest Income                   88.0
# 87          90             Interest Expense                   88.0
# 88          91  Gain/Loss on Sales of Asset                   88.0
# 89          92                 Other Income                   88.0
#
#     AccountDescriptionNv1  AccountDescriptionNv6  AccountDescriptionNv5  \
# 22                    1.0                    NaN                    NaN
# 86                   47.0                    NaN                    NaN
# 87                   47.0                    NaN                    NaN
# 88                   47.0                    NaN                    NaN
# 89                   47.0                    NaN                    NaN
#
#     AccountDescriptionNv4   AccountType
# 22                    NaN        Assets
# 86                    NaN       Revenue
# 87                    NaN  Expenditures
# 88                    NaN       Revenue
# 89                    NaN       Revenue

# %%
#Separando os registros para ajuste de hierarquia
AccAux2 = DimAccount_trat7[DimAccount_trat7['ParentAccountKey2'].isna() & DimAccount_trat7['ParentAccountKey'].notna()]
AccAux2 = AccAux2.rename(columns={"AccountDescription":"AccountDescriptionNv2","ParentAccountKey":"AccountDescriptionNv1","ParentAccountKey2":"AccountDescriptionNv6","ParentAccountKey3":"AccountDescriptionNv5","ParentAccountKey4":"AccountDescriptionNv4","ParentAccountKey5":"AccountDescriptionNv3"})
AccAux2.head()
# Out:
#     AccountKey AccountDescriptionNv2  AccountDescriptionNv1  \
# 91          94                 Taxes                   47.0
#
#     AccountDescriptionNv6  AccountDescriptionNv5  AccountDescriptionNv4  \
# 91                    NaN                    NaN                    NaN
#
#     AccountDescriptionNv3   AccountType
# 91                    NaN  Expenditures

# %%
#Junção dos registros
DimAccount_trat8 = pd.concat([AccAux6,AccAux5,AccAux4,AccAux3,AccAux2])
DimAccount_trat8
# Out:
#     AccountKey AccountDescriptionNv6 AccountDescriptionNv5  \
# 29          31   Salary & Other Comp                  30.0
# 30          32             Insurance                  30.0
# 31          33            Warranties                  30.0
# 50          52    Intercompany Sales                  51.0
# 98         101           Trade Sales                  51.0
# ..         ...                   ...                   ...
# 87          90                   NaN                   NaN
# 88          91                   NaN                   NaN
# 89          92                   NaN                   NaN
# 90          93                   NaN                   NaN
# 91          94                   NaN                   NaN
#
#    AccountDescriptionNv4        AccountDescriptionNv3 AccountDescriptionNv2  \
# 29                  27.0                         26.0                  25.0
# 30                  27.0                         26.0                  25.0
# 31                  27.0                         26.0                  25.0
# 50                  50.0                         49.0                  48.0
# 98                  50.0                         49.0                  48.0
# ..                   ...                          ...                   ...
# 87                   NaN             Interest Expense                  88.0
# 88                   NaN  Gain/Loss on Sales of Asset                  88.0
# 89                   NaN                 Other Income                  88.0
# 90                   NaN        Curr Xchg Gain/(Loss)                  88.0
# 91                   NaN                          NaN                 Taxes
#
#     AccountDescriptionNv1   AccountType
# 29                    1.0   Liabilities
# 30                    1.0   Liabilities
# 31                    1.0   Liabilities
# 50                   47.0       Revenue
# 98                   47.0       Revenue
# ..                    ...           ...
# 87                   47.0  Expenditures
# 88                   47.0       Revenue
# 89                   47.0       Revenue
# 90                   47.0       Revenue
# 91                   47.0  Expenditures
#
# [68 rows x 8 columns]

# %%
#Substituindo os códigos pelos nomes
AccName = pd.Series(DimAccount.AccountDescription.values,index=DimAccount.AccountKey).to_dict()
DimAccount_trat9 = DimAccount_trat8.replace({"AccountDescriptionNv6": AccName,"AccountDescriptionNv5": AccName,"AccountDescriptionNv4": AccName,"AccountDescriptionNv3": AccName,"AccountDescriptionNv2": AccName,"AccountDescriptionNv1": AccName})
DimAccount_trat9
# Out:
#     AccountKey AccountDescriptionNv6 AccountDescriptionNv5  \
# 29          31   Salary & Other Comp      Accrued Expenses
# 30          32             Insurance      Accrued Expenses
# 31          33            Warranties      Accrued Expenses
# 50          52    Intercompany Sales           Gross Sales
# 98         101           Trade Sales           Gross Sales
# ..         ...                   ...                   ...
# 87          90                   NaN                   NaN
# 88          91                   NaN                   NaN
# 89          92                   NaN                   NaN
# 90          93                   NaN                   NaN
# 91          94                   NaN                   NaN
#
#    AccountDescriptionNv4        AccountDescriptionNv3  \
# 29   Current Liabilities                  Liabilities
# 30   Current Liabilities                  Liabilities
# 31   Current Liabilities                  Liabilities
# 50             Net Sales                 Gross Margin
# 98             Net Sales                 Gross Margin
# ..                   ...                          ...
# 87                   NaN             Interest Expense
# 88                   NaN  Gain/Loss on Sales of Asset
# 89                   NaN                 Other Income
# 90                   NaN        Curr Xchg Gain/(Loss)
# 91                   NaN                          NaN
#
#             AccountDescriptionNv2 AccountDescriptionNv1   AccountType
# 29  Liabilities and Owners Equity         Balance Sheet   Liabilities
# 30  Liabilities and Owners Equity         Balance Sheet   Liabilities
# 31  Liabilities and Owners Equity         Balance Sheet   Liabilities
# 50               Operating Profit            Net Income       Revenue
# 98               Operating Profit            Net Income       Revenue
# ..                            ...                   ...           ...
# 87       Other Income and Expense            Net Income  Expenditures
# 88       Other Income and Expense            Net Income       Revenue
# 89       Other Income and Expense            Net Income       Revenue
# 90       Other Income and Expense            Net Income       Revenue
# 91                          Taxes            Net Income  Expenditures
#
# [68 rows x 8 columns]

# %% [markdown]
# ## DimScenario

# %%
DimScenario.head()
# Out:
#    ScenarioKey ScenarioName
# 0            1       Actual
# 1            2       Budget
# 2            3     Forecast

# %% [markdown]
# ### Ter a informações contidas na tabela DimScenario como uma tabela separada é desnecessário e irei levar para a FactFinance

# %%
FactFinance_trat3 = pd.merge(FactFinance_trat2, DimScenario, how='left', on = 'ScenarioKey')

# %% [markdown]
# ## FactFinance

# %%
FactFinance_trat3.head()
# Out:
#    FinanceKey   DateKey  OrganizationKey  DepartmentGroupKey  ScenarioKey  \
# 0           1  20101229                3                   1            1
# 1           2  20101229                3                   1            2
# 2           3  20101229                3                   1            2
# 3           4  20101229                3                   1            1
# 4           5  20101229                3                   1            1
#
#    AccountKey   Amount       Date ScenarioName
# 0          60  22080.0 2010-12-29       Actual
# 1          60  20200.0 2010-12-29       Budget
# 2          61   2000.0 2010-12-29       Budget
# 3          61   2208.0 2010-12-29       Actual
# 4          62   1546.0 2010-12-29       Actual

# %%
#Seleção das colunas
FactFinance_trat4 = FactFinance_trat3[["DateKey","OrganizationKey","DepartmentGroupKey","AccountKey","Amount","ScenarioName"]]
FactFinance_trat4.head()
# Out:
#     DateKey  OrganizationKey  DepartmentGroupKey  AccountKey   Amount  \
# 0  20101229                3                   1          60  22080.0
# 1  20101229                3                   1          60  20200.0
# 2  20101229                3                   1          61   2000.0
# 3  20101229                3                   1          61   2208.0
# 4  20101229                3                   1          62   1546.0
#
#   ScenarioName
# 0       Actual
# 1       Budget
# 2       Budget
# 3       Actual
# 4       Actual

# %% [markdown]
# ### DimDate

# %%
DimDate.head()
# Out:
#     DateKey FullDateAlternateKey  DayNumberOfWeek EnglishDayNameOfWeek  \
# 0  20050101           2005-01-01                7             Saturday
# 1  20050102           2005-01-02                1               Sunday
# 2  20050103           2005-01-03                2               Monday
# 3  20050104           2005-01-04                3              Tuesday
# 4  20050105           2005-01-05                4            Wednesday
#
#   SpanishDayNameOfWeek FrenchDayNameOfWeek  DayNumberOfMonth  DayNumberOfYear  \
# 0               Sábado              Samedi                 1                1
# 1              Domingo            Dimanche                 2                2
# 2                Lunes               Lundi                 3                3
# 3               Martes               Mardi                 4                4
# 4            Miércoles            Mercredi                 5                5
#
#    WeekNumberOfYear EnglishMonthName SpanishMonthName FrenchMonthName  \
# 0                 1          January            Enero         Janvier
# 1                 2          January            Enero         Janvier
# 2                 2          January            Enero         Janvier
# 3                 2          January            Enero         Janvier
# 4                 2          January            Enero         Janvier
#
#    MonthNumberOfYear  CalendarQuarter  CalendarYear  CalendarSemester  \
# 0                  1                1          2005                 1
# 1                  1                1          2005                 1
# 2                  1                1          2005                 1
# 3                  1                1          2005                 1
# 4                  1                1          2005                 1
#
#    FiscalQuarter  FiscalYear  FiscalSemester
# 0              3        2005               2
# 1              3        2005               2
# 2              3        2005               2
# 3              3        2005               2
# 4              3        2005               2

# %%
#Seleção das colunas, desconsiderando nomes em espanhol e frances
DimDate_trat = DimDate[["DateKey","FullDateAlternateKey","DayNumberOfWeek","EnglishDayNameOfWeek","DayNumberOfMonth","DayNumberOfYear","WeekNumberOfYear","EnglishMonthName","MonthNumberOfYear","CalendarQuarter","CalendarYear","CalendarSemester","FiscalQuarter","FiscalYear","FiscalSemester"]]
DimDate_trat.head()
# Out:
#     DateKey FullDateAlternateKey  DayNumberOfWeek EnglishDayNameOfWeek  \
# 0  20050101           2005-01-01                7             Saturday
# 1  20050102           2005-01-02                1               Sunday
# 2  20050103           2005-01-03                2               Monday
# 3  20050104           2005-01-04                3              Tuesday
# 4  20050105           2005-01-05                4            Wednesday
#
#    DayNumberOfMonth  DayNumberOfYear  WeekNumberOfYear EnglishMonthName  \
# 0                 1                1                 1          January
# 1                 2                2                 2          January
# 2                 3                3                 2          January
# 3                 4                4                 2          January
# 4                 5                5                 2          January
#
#    MonthNumberOfYear  CalendarQuarter  CalendarYear  CalendarSemester  \
# 0                  1                1          2005                 1
# 1                  1                1          2005                 1
# 2                  1                1          2005                 1
# 3                  1                1          2005                 1
# 4                  1                1          2005                 1
#
#    FiscalQuarter  FiscalYear  FiscalSemester
# 0              3        2005               2
# 1              3        2005               2
# 2              3        2005               2
# 3              3        2005               2
# 4              3        2005               2

# %%
#Renomeação das colunas
DimDate_trat2 = DimDate_trat.rename(columns={"EnglishDayNameOfWeek":"DayNameOfWeek","EnglishMonthName":"MonthName"})
DimDate_trat2.head()
# Out:
#     DateKey FullDateAlternateKey  DayNumberOfWeek DayNameOfWeek  \
# 0  20050101           2005-01-01                7      Saturday
# 1  20050102           2005-01-02                1        Sunday
# 2  20050103           2005-01-03                2        Monday
# 3  20050104           2005-01-04                3       Tuesday
# 4  20050105           2005-01-05                4     Wednesday
#
#    DayNumberOfMonth  DayNumberOfYear  WeekNumberOfYear MonthName  \
# 0                 1                1                 1   January
# 1                 2                2                 2   January
# 2                 3                3                 2   January
# 3                 4                4                 2   January
# 4                 5                5                 2   January
#
#    MonthNumberOfYear  CalendarQuarter  CalendarYear  CalendarSemester  \
# 0                  1                1          2005                 1
# 1                  1                1          2005                 1
# 2                  1                1          2005                 1
# 3                  1                1          2005                 1
# 4                  1                1          2005                 1
#
#    FiscalQuarter  FiscalYear  FiscalSemester
# 0              3        2005               2
# 1              3        2005               2
# 2              3        2005               2
# 3              3        2005               2
# 4              3        2005               2

# %%
#Remoção de registros anteriores a agosto de 2011, onde não tem dados contínuos
regRemovDate = DimDate_trat2.DateKey[DimDate_trat2['DateKey'] >= 20110801].tolist()
regRemovDate
# Out:
# [20110801,
#  20110802,
#  20110803,
#  20110804,
#  20110805,
#  20110806,
#  20110807,
#  20110808,
#  20110809,
#  20110810,
#  20110811,
#  20110812,
#  20110813,
#  20110814,
#  20110815,
#  20110816,
#  20110817,
#  20110818,
#  20110819,
#  20110820,
#  20110821,
#  20110822,
#  20110823,
#  20110824,
#  20110825,
#  20110826,
#  20110827,
#  20110828,
#  20110829,
#  20110830,
#  20110831,
#  20110901,
#  20110902,
#  20110903,
#  20110904,
#  20110905,
#  20110906,
#  20110907,
#  20110908,
#  20110909,
#  20110910,
#  20110911,
#  20110912,
#  20110913,
#  20110914,
#  20110915,
#  20110916,
#  20110917,
#  20110918,
#  20110919,
#  20110920,
#  20110921,
#  20110922,
#  20110923,
#  20110924,
#  20110925,
#  20110926,
#  20110927,
#  20110928,
#  20110929,
#  20110930,
#  20111001,
#  20111002,
#  20111003,
#  20111004,
#  20111005,
#  20111006,
#  20111007,
#  20111008,
#  20111009,
#  20111010,
#  20111011,
#  20111012,
#  20111013,
#  20111014,
#  20111015,
#  20111016,
#  20111017,
#  20111018,
#  20111019,
#  20111020,
#  20111021,
#  20111022,
#  20111023,
#  20111024,
#  20111025,
#  20111026,
#  20111027,
#  20111028,
#  20111029,
#  20111030,
#  20111031,
#  20111101,
#  20111102,
#  20111103,
#  20111104,
#  20111105,
#  20111106,
#  20111107,
#  20111108,
#  20111109,
#  20111110,
#  20111111,
#  20111112,
#  20111113,
#  20111114,
#  20111115,
#  20111116,
#  20111117,
#  20111118,
#  20111119,
#  20111120,
#  20111121,
#  20111122,
#  20111123,
#  20111124,
#  20111125,
#  20111126,
#  20111127,
#  20111128,
#  20111129,
#  20111130,
#  20111201,
#  20111202,
#  20111203,
#  20111204,
#  20111205,
#  20111206,
#  20111207,
#  20111208,
#  20111209,
#  20111210,
#  20111211,
#  20111212,
#  20111213,
#  20111214,
#  20111215,
#  20111216,
#  20111217,
#  20111218,
#  20111219,
#  20111220,
#  20111221,
#  20111222,
#  20111223,
#  20111224,
#  20111225,
#  20111226,
#  20111227,
#  20111228,
#  20111229,
#  20111230,
#  20111231,
#  20120101,
#  20120102,
#  20120103,
#  20120104,
#  20120105,
#  20120106,
#  20120107,
#  20120108,
#  20120109,
#  20120110,
#  20120111,
#  20120112,
#  20120113,
#  20120114,
#  20120115,
#  20120116,
#  20120117,
#  20120118,
#  20120119,
#  20120120,
#  20120121,
#  20120122,
#  20120123,
#  20120124,
#  20120125,
#  20120126,
#  20120127,
#  20120128,
#  20120129,
#  20120130,
#  20120131,
#  20120201,
#  20120202,
#  20120203,
#  20120204,
#  20120205,
#  20120206,
#  20120207,
#  20120208,
#  20120209,
#  20120210,
#  20120211,
#  20120212,
#  20120213,
#  20120214,
#  20120215,
#  20120216,
#  20120217,
#  20120218,
#  20120219,
#  20120220,
#  20120221,
#  20120222,
#  20120223,
#  20120224,
#  20120225,
#  20120226,
#  20120227,
#  20120228,
#  20120229,
#  20120301,
#  20120302,
#  20120303,
#  20120304,
#  20120305,
#  20120306,
#  20120307,
#  20120308,
#  20120309,
#  20120310,
#  20120311,
#  20120312,
#  20120313,
#  20120314,
#  20120315,
#  20120316,
#  20120317,
#  20120318,
#  20120319,
#  20120320,
#  20120321,
#  20120322,
#  20120323,
#  20120324,
#  20120325,
#  20120326,
#  20120327,
#  20120328,
#  20120329,
#  20120330,
#  20120331,
#  20120401,
#  20120402,
#  20120403,
#  20120404,
#  20120405,
#  20120406,
#  20120407,
#  20120408,
#  20120409,
#  20120410,
#  20120411,
#  20120412,
#  20120413,
#  20120414,
#  20120415,
#  20120416,
#  20120417,
#  20120418,
#  20120419,
#  20120420,
#  20120421,
#  20120422,
#  20120423,
#  20120424,
#  20120425,
#  20120426,
#  20120427,
#  20120428,
#  20120429,
#  20120430,
#  20120501,
#  20120502,
#  20120503,
#  20120504,
#  20120505,
#  20120506,
#  20120507,
#  20120508,
#  20120509,
#  20120510,
#  20120511,
#  20120512,
#  20120513,
#  20120514,
#  20120515,
#  20120516,
#  20120517,
#  20120518,
#  20120519,
#  20120520,
#  20120521,
#  20120522,
#  20120523,
#  20120524,
#  20120525,
#  20120526,
#  20120527,
#  20120528,
#  20120529,
#  20120530,
#  20120531,
#  20120601,
#  20120602,
#  20120603,
#  20120604,
#  20120605,
#  20120606,
#  20120607,
#  20120608,
#  20120609,
#  20120610,
#  20120611,
#  20120612,
#  20120613,
#  20120614,
#  20120615,
#  20120616,
#  20120617,
#  20120618,
#  20120619,
#  20120620,
#  20120621,
#  20120622,
#  20120623,
#  20120624,
#  20120625,
#  20120626,
#  20120627,
#  20120628,
#  20120629,
#  20120630,
#  20120701,
#  20120702,
#  20120703,
#  20120704,
#  20120705,
#  20120706,
#  20120707,
#  20120708,
#  20120709,
#  20120710,
#  20120711,
#  20120712,
#  20120713,
#  20120714,
#  20120715,
#  20120716,
#  20120717,
#  20120718,
#  20120719,
#  20120720,
#  20120721,
#  20120722,
#  20120723,
#  20120724,
#  20120725,
#  20120726,
#  20120727,
#  20120728,
#  20120729,
#  20120730,
#  20120731,
#  20120801,
#  20120802,
#  20120803,
#  20120804,
#  20120805,
#  20120806,
#  20120807,
#  20120808,
#  20120809,
#  20120810,
#  20120811,
#  20120812,
#  20120813,
#  20120814,
#  20120815,
#  20120816,
#  20120817,
#  20120818,
#  20120819,
#  20120820,
#  20120821,
#  20120822,
#  20120823,
#  20120824,
#  20120825,
#  20120826,
#  20120827,
#  20120828,
#  20120829,
#  20120830,
#  20120831,
#  20120901,
#  20120902,
#  20120903,
#  20120904,
#  20120905,
#  20120906,
#  20120907,
#  20120908,
#  20120909,
#  20120910,
#  20120911,
#  20120912,
#  20120913,
#  20120914,
#  20120915,
#  20120916,
#  20120917,
#  20120918,
#  20120919,
#  20120920,
#  20120921,
#  20120922,
#  20120923,
#  20120924,
#  20120925,
#  20120926,
#  20120927,
#  20120928,
#  20120929,
#  20120930,
#  20121001,
#  20121002,
#  20121003,
#  20121004,
#  20121005,
#  20121006,
#  20121007,
#  20121008,
#  20121009,
#  20121010,
#  20121011,
#  20121012,
#  20121013,
#  20121014,
#  20121015,
#  20121016,
#  20121017,
#  20121018,
#  20121019,
#  20121020,
#  20121021,
#  20121022,
#  20121023,
#  20121024,
#  20121025,
#  20121026,
#  20121027,
#  20121028,
#  20121029,
#  20121030,
#  20121031,
#  20121101,
#  20121102,
#  20121103,
#  20121104,
#  20121105,
#  20121106,
#  20121107,
#  20121108,
#  20121109,
#  20121110,
#  20121111,
#  20121112,
#  20121113,
#  20121114,
#  20121115,
#  20121116,
#  20121117,
#  20121118,
#  20121119,
#  20121120,
#  20121121,
#  20121122,
#  20121123,
#  20121124,
#  20121125,
#  20121126,
#  20121127,
#  20121128,
#  20121129,
#  20121130,
#  20121201,
#  20121202,
#  20121203,
#  20121204,
#  20121205,
#  20121206,
#  20121207,
#  20121208,
#  20121209,
#  20121210,
#  20121211,
#  20121212,
#  20121213,
#  20121214,
#  20121215,
#  20121216,
#  20121217,
#  20121218,
#  20121219,
#  20121220,
#  20121221,
#  20121222,
#  20121223,
#  20121224,
#  20121225,
#  20121226,
#  20121227,
#  20121228,
#  20121229,
#  20121230,
#  20121231,
#  20130101,
#  20130102,
#  20130103,
#  20130104,
#  20130105,
#  20130106,
#  20130107,
#  20130108,
#  20130109,
#  20130110,
#  20130111,
#  20130112,
#  20130113,
#  20130114,
#  20130115,
#  20130116,
#  20130117,
#  20130118,
#  20130119,
#  20130120,
#  20130121,
#  20130122,
#  20130123,
#  20130124,
#  20130125,
#  20130126,
#  20130127,
#  20130128,
#  20130129,
#  20130130,
#  20130131,
#  20130201,
#  20130202,
#  20130203,
#  20130204,
#  20130205,
#  20130206,
#  20130207,
#  20130208,
#  20130209,
#  20130210,
#  20130211,
#  20130212,
#  20130213,
#  20130214,
#  20130215,
#  20130216,
#  20130217,
#  20130218,
#  20130219,
#  20130220,
#  20130221,
#  20130222,
#  20130223,
#  20130224,
#  20130225,
#  20130226,
#  20130227,
#  20130228,
#  20130301,
#  20130302,
#  20130303,
#  20130304,
#  20130305,
#  20130306,
#  20130307,
#  20130308,
#  20130309,
#  20130310,
#  20130311,
#  20130312,
#  20130313,
#  20130314,
#  20130315,
#  20130316,
#  20130317,
#  20130318,
#  20130319,
#  20130320,
#  20130321,
#  20130322,
#  20130323,
#  20130324,
#  20130325,
#  20130326,
#  20130327,
#  20130328,
#  20130329,
#  20130330,
#  20130331,
#  20130401,
#  20130402,
#  20130403,
#  20130404,
#  20130405,
#  20130406,
#  20130407,
#  20130408,
#  20130409,
#  20130410,
#  20130411,
#  20130412,
#  20130413,
#  20130414,
#  20130415,
#  20130416,
#  20130417,
#  20130418,
#  20130419,
#  20130420,
#  20130421,
#  20130422,
#  20130423,
#  20130424,
#  20130425,
#  20130426,
#  20130427,
#  20130428,
#  20130429,
#  20130430,
#  20130501,
#  20130502,
#  20130503,
#  20130504,
#  20130505,
#  20130506,
#  20130507,
#  20130508,
#  20130509,
#  20130510,
#  20130511,
#  20130512,
#  20130513,
#  20130514,
#  20130515,
#  20130516,
#  20130517,
#  20130518,
#  20130519,
#  20130520,
#  20130521,
#  20130522,
#  20130523,
#  20130524,
#  20130525,
#  20130526,
#  20130527,
#  20130528,
#  20130529,
#  20130530,
#  20130531,
#  20130601,
#  20130602,
#  20130603,
#  20130604,
#  20130605,
#  20130606,
#  20130607,
#  20130608,
#  20130609,
#  20130610,
#  20130611,
#  20130612,
#  20130613,
#  20130614,
#  20130615,
#  20130616,
#  20130617,
#  20130618,
#  20130619,
#  20130620,
#  20130621,
#  20130622,
#  20130623,
#  20130624,
#  20130625,
#  20130626,
#  20130627,
#  20130628,
#  20130629,
#  20130630,
#  20130701,
#  20130702,
#  20130703,
#  20130704,
#  20130705,
#  20130706,
#  20130707,
#  20130708,
#  20130709,
#  20130710,
#  20130711,
#  20130712,
#  20130713,
#  20130714,
#  20130715,
#  20130716,
#  20130717,
#  20130718,
#  20130719,
#  20130720,
#  20130721,
#  20130722,
#  20130723,
#  20130724,
#  20130725,
#  20130726,
#  20130727,
#  20130728,
#  20130729,
#  20130730,
#  20130731,
#  20130801,
#  20130802,
#  20130803,
#  20130804,
#  20130805,
#  20130806,
#  20130807,
#  20130808,
#  20130809,
#  20130810,
#  20130811,
#  20130812,
#  20130813,
#  20130814,
#  20130815,
#  20130816,
#  20130817,
#  20130818,
#  20130819,
#  20130820,
#  20130821,
#  20130822,
#  20130823,
#  20130824,
#  20130825,
#  20130826,
#  20130827,
#  20130828,
#  20130829,
#  20130830,
#  20130831,
#  20130901,
#  20130902,
#  20130903,
#  20130904,
#  20130905,
#  20130906,
#  20130907,
#  20130908,
#  20130909,
#  20130910,
#  20130911,
#  20130912,
#  20130913,
#  20130914,
#  20130915,
#  20130916,
#  20130917,
#  20130918,
#  20130919,
#  20130920,
#  20130921,
#  20130922,
#  20130923,
#  20130924,
#  20130925,
#  20130926,
#  20130927,
#  20130928,
#  20130929,
#  20130930,
#  20131001,
#  20131002,
#  20131003,
#  20131004,
#  20131005,
#  20131006,
#  20131007,
#  20131008,
#  20131009,
#  20131010,
#  20131011,
#  20131012,
#  20131013,
#  20131014,
#  20131015,
#  20131016,
#  20131017,
#  20131018,
#  20131019,
#  20131020,
#  20131021,
#  20131022,
#  20131023,
#  20131024,
#  20131025,
#  20131026,
#  20131027,
#  20131028,
#  20131029,
#  20131030,
#  20131031,
#  20131101,
#  20131102,
#  20131103,
#  20131104,
#  20131105,
#  20131106,
#  20131107,
#  20131108,
#  20131109,
#  20131110,
#  20131111,
#  20131112,
#  20131113,
#  20131114,
#  20131115,
#  20131116,
#  20131117,
#  20131118,
#  20131119,
#  20131120,
#  20131121,
#  20131122,
#  20131123,
#  20131124,
#  20131125,
#  20131126,
#  20131127,
#  20131128,
#  20131129,
#  20131130,
#  20131201,
#  20131202,
#  20131203,
#  20131204,
#  20131205,
#  20131206,
#  20131207,
#  20131208,
#  20131209,
#  20131210,
#  20131211,
#  20131212,
#  20131213,
#  20131214,
#  20131215,
#  20131216,
#  20131217,
#  20131218,
#  20131219,
#  20131220,
#  20131221,
#  20131222,
#  20131223,
#  20131224,
#  20131225,
#  20131226,
#  20131227,
#  20131228,
#  20131229,
#  20131230,
#  20131231,
#  20140101,
#  20140102,
#  20140103,
#  20140104,
#  20140105,
#  20140106,
#  20140107,
#  20140108,
#  20140109,
#  20140110,
#  20140111,
#  20140112,
#  20140113,
#  20140114,
#  20140115,
#  20140116,
#  20140117,
#  20140118,
#  20140119,
#  20140120,
#  20140121,
#  20140122,
#  20140123,
#  20140124,
#  20140125,
#  20140126,
#  20140127,
#  20140128,
#  20140129,
#  20140130,
#  20140131,
#  20140201,
#  20140202,
#  20140203,
#  20140204,
#  20140205,
#  20140206,
#  20140207,
#  20140208,
#  20140209,
#  20140210,
#  20140211,
#  20140212,
#  20140213,
#  20140214,
#  20140215,
#  20140216,
#  20140217,
#  20140218,
#  20140219,
#  20140220,
#  20140221,
#  20140222,
#  20140223,
#  20140224,
#  20140225,
#  20140226,
#  20140227,
#  20140228,
#  20140301,
#  20140302,
#  20140303,
#  20140304,
#  20140305,
#  20140306,
#  20140307,
#  20140308,
#  20140309,
#  20140310,
#  20140311,
#  20140312,
#  20140313,
#  20140314,
#  20140315,
#  20140316,
#  20140317,
#  20140318,
#  20140319,
#  20140320,
#  20140321,
#  20140322,
#  20140323,
#  20140324,
#  20140325,
#  20140326,
#  20140327,
#  20140328,
#  20140329,
#  20140330,
#  20140331,
#  20140401,
#  20140402,
#  20140403,
#  20140404,
#  20140405,
#  20140406,
#  20140407,
#  20140408,
#  20140409,
#  20140410,
#  20140411,
#  20140412,
#  20140413,
#  20140414,
#  20140415,
#  20140416,
#  20140417,
#  20140418,
#  20140419,
#  20140420,
#  20140421,
#  20140422,
#  20140423,
#  20140424,
#  20140425,
#  20140426,
#  ...]

# %%
#Removendo na fato os registros referentes a estes registros
FactFinance_trat5 = FactFinance_trat4[FactFinance_trat4['DateKey'].isin(regRemovDate)]
DimDate_trat3 = DimDate_trat2[DimDate_trat2['DateKey'].isin(regRemovDate)]

# %%
#Identificação da data máxima na fato
dataMaxReg = FactFinance_trat5.DateKey.max()

# %%
#Removendo na DimDate os registros referentes a estes registros
FactFinance_trat6 = FactFinance_trat5[FactFinance_trat5['DateKey'] <= dataMaxReg]
DimDate_trat4 = DimDate_trat3[DimDate_trat3['DateKey'] <= dataMaxReg]

# %%
DimDate_trat5 = DimDate_trat4
DimDate_trat5.FullDateAlternateKey = DimDate_trat5.FullDateAlternateKey.str.replace('-','/')
# Out:
# C:\Users\gab\AppData\Local\Temp\ipykernel_17204\3426947168.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DimDate_trat5.FullDateAlternateKey = DimDate_trat5.FullDateAlternateKey.str.replace('-','/')

# %%
DimDate_trat5
# Out:
#        DateKey FullDateAlternateKey  DayNumberOfWeek DayNameOfWeek  \
# 2403  20110801           2011/08/01                2        Monday
# 2404  20110802           2011/08/02                3       Tuesday
# 2405  20110803           2011/08/03                4     Wednesday
# 2406  20110804           2011/08/04                5      Thursday
# 2407  20110805           2011/08/05                6        Friday
# ...        ...                  ...              ...           ...
# 3279  20131224           2013/12/24                3       Tuesday
# 3280  20131225           2013/12/25                4     Wednesday
# 3281  20131226           2013/12/26                5      Thursday
# 3282  20131227           2013/12/27                6        Friday
# 3283  20131228           2013/12/28                7      Saturday
#
#       DayNumberOfMonth  DayNumberOfYear  WeekNumberOfYear MonthName  \
# 2403                 1              213                32    August
# 2404                 2              214                32    August
# 2405                 3              215                32    August
# 2406                 4              216                32    August
# 2407                 5              217                32    August
# ...                ...              ...               ...       ...
# 3279                24              358                52  December
# 3280                25              359                52  December
# 3281                26              360                52  December
# 3282                27              361                52  December
# 3283                28              362                52  December
#
#       MonthNumberOfYear  CalendarQuarter  CalendarYear  CalendarSemester  \
# 2403                  8                3          2011                 2
# 2404                  8                3          2011                 2
# 2405                  8                3          2011                 2
# 2406                  8                3          2011                 2
# 2407                  8                3          2011                 2
# ...                 ...              ...           ...               ...
# 3279                 12                4          2013                 2
# 3280                 12                4          2013                 2
# 3281                 12                4          2013                 2
# 3282                 12                4          2013                 2
# 3283                 12                4          2013                 2
#
#       FiscalQuarter  FiscalYear  FiscalSemester
# 2403              1        2011               1
# 2404              1        2011               1
# 2405              1        2011               1
# 2406              1        2011               1
# 2407              1        2011               1
# ...             ...         ...             ...
# 3279              2        2013               1
# 3280              2        2013               1
# 3281              2        2013               1
# 3282              2        2013               1
# 3283              2        2013               1
#
# [881 rows x 15 columns]

# %% [markdown]
# ## Escrita no banco de dados

# %%
#Criação de conexão ao banco de dados para leitura
server_name = "DESKTOP-9RK4J8O"
db_name = "AdventureWorksTrat"
connection_str =  'Driver={SQL Server};' + 'Server=' + server_name + ";Database=" + db_name + ";Trusted_Connection=yes;"

connection_url = URL.create("mssql+pyodbc", query={"odbc_connect": connection_str})
engine = create_engine(connection_url)
con = engine.connect()

# %%
#Escrever as tabelas
FactFinance_trat6.to_sql("FactFinance", con, index = False,if_exists='replace')
DimAccount_trat9.to_sql("DimAccount", con, index = False,if_exists='replace')
DimDate_trat5.to_sql("DimDate", con, index = False,if_exists='replace')
DimDepartmentGroup_trat3.to_sql("DimDepartmentGroup", con, index = False,if_exists='replace')
DimOrganization_trat7.to_sql("DimOrganization", con, index = False,if_exists='replace')
# Out:
# -1
